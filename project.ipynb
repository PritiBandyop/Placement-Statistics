# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csvFile = pd.read_csv('/CollegePlacement (2).csv')
print(csvFile)
# Out:
#      Python  DeepLearning  MachineLearning  BigData  CloudComputing Placement
# 0      0.80          0.57             0.63     0.50            0.34       Yes
# 1      0.81          0.90             0.62     0.71            0.92        No
# 2      0.49          0.69             0.62     0.64            0.41        No
# 3      0.40          0.94             0.60     0.26            0.47        No
# 4      0.31          0.87             1.00     0.23            0.99        No
# ..      ...           ...              ...      ...             ...       ...
# 195    0.47          0.13             0.78     0.10            0.11       Yes
# 196    0.14          0.49             0.19     0.33            0.85       Yes
# 197    0.95          0.65             0.62     0.74            0.61       Yes
# 198    0.60          0.99             0.66     0.71            0.93       Yes
# 199    0.87          0.23             0.97     0.45            0.42       Yes
#
# [200 rows x 6 columns]

# %%
csvFile.head(200)
# Out:
#      Python  DeepLearning  MachineLearning  BigData  CloudComputing Placement
# 0      0.80          0.57             0.63     0.50            0.34       Yes
# 1      0.81          0.90             0.62     0.71            0.92        No
# 2      0.49          0.69             0.62     0.64            0.41        No
# 3      0.40          0.94             0.60     0.26            0.47        No
# 4      0.31          0.87             1.00     0.23            0.99        No
# ..      ...           ...              ...      ...             ...       ...
# 195    0.47          0.13             0.78     0.10            0.11       Yes
# 196    0.14          0.49             0.19     0.33            0.85       Yes
# 197    0.95          0.65             0.62     0.74            0.61       Yes
# 198    0.60          0.99             0.66     0.71            0.93       Yes
# 199    0.87          0.23             0.97     0.45            0.42       Yes
#
# [200 rows x 6 columns]

# %%
csvFile.isnull().sum()
# Out:
# Python             0
# DeepLearning       0
# MachineLearning    0
# BigData            0
# CloudComputing     0
# Placement          0
# dtype: int64

# %%
csvFile.columns
# Out:
# Index(['Python', 'DeepLearning', 'MachineLearning', 'BigData',
#        'CloudComputing', 'Placement'],
#       dtype='object')

# %%
array = csvFile['Placement'].to_numpy()
print(array)
# Out:
# ['Yes' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No'
#  'No' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes'
#  'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'No'
#  'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'Yes'
#  'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes'
#  'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'No' 'No' 'No' 'No'
#  'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'Yes'
#  'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes'
#  'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'No' 'No' 'No' 'No' 'No' 'No' 'No'
#  'No' 'No' 'No' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes'
#  'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes'
#  'Yes' 'Yes' 'Yes' 'Yes' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No' 'No'
#  'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes'
# ...

# %%
ar1 = csvFile['Python'].to_numpy()
a1=ar1*100
print(a1)
# Out:
# [ 80.  81.  49.  40.  31.  14.  21.   8.  81.  31.  28.  22.  86.  91.
#   88.  11.   8.  38.  89.  30.   9.  40.  12.  70.  45.  16.  13.   8.
#   48.  27.  47.  73.  99.   3.  73.  91.  15.  83.   2.  53.  38.  56.
#    0.   2.  34.  45.  54.  19.  52.  19.  37.  94.  10.  74.  97.  74.
#   56.  38.  90.   0.  98.  24.  55.  22.  33.  86.   7.  92.  35.  63.
#   84.  61.  90.  34.  27.  63.  57.  75.  41.  88.  67.  90.  87.  75.
#   27.  74.   5.  79.  24.  70.  80.  38.  37.  28.  53.  19.   2.  86.
#   97.  17.  60.  71.  53.  87.  24.  71.   0.  81.  73.  39.  15.  33.
#   88.  62.   9.  39.  67.  76.  12.  88.  67.  20.  95.  28.  15.  82.
#   58.   4.  16.  56.  25.  50.  84. 100.  19.  14.  59.  90.  80.  67.
#   80.  75.  77.  57.  84.  65.  60.  12.  84.  23.  81.   3. 100.  93.
#   47.  61.  18.  87.  68.  83.  15.  99.  69.  83.  32.  86.   3.   7.
#   34.  99.  13.  70.  24.  71.  10.  12.   5.  26.  65.  86.  16.  39.
# ...

# %%
ar2 = csvFile['DeepLearning'].to_numpy()
a2=ar2*100
print(a2)
# Out:
# [ 57.  90.  69.  94.  87.  87.  80.  78.  17.  28.  13.  63.  67.  21.
#   83.  35.  97.  46.   1.  37.  16.  56.  37.  38.  80.  45.  24.  17.
#   29.  24.  32.  13.  30.  33.  99.  43.  66.  65.  26.  22.  44.  57.
#   36.  76.  33.  83.  49.   2.  79.  99.  46.  61.  13.  26.  75.  16.
#   63.  51.  14.  55.  49.  39.   2.  41.  88.  58.  63.  48.  20.  62.
#   58.   9.  59.   7.  52.  20.  76.  86.  19.  71.  59.  75.   4.   2.
#   11.  84.  18.  58.  34.  82.  62.  45.  88.  70.  82.  56.  18.   3.
#    1.   7.  51.  71.   9.  21.  51.  47.  56.   9.  96.   5.  88.  98.
#   61.  92.  39.  40.  63.  95.  20.  25.  11.  39.  59.  82.  91.  69.
#   93.  20.  33.  37.  74.   4.  43.  37.  18.  12.  97.  69.  14.  52.
#   91.  15.  21.  36.  91.  17.  84.  14.  17.  62.  70.  11.  13.  43.
#   23.  49.  70.  55.  60.  85.  92.  56.  70.  11.  92.  83.  92.  90.
#   92.  42.  77.   2.  94.  74.  23.  68.  72.  83.  69.  35.  52.  69.
# ...

# %%
csvFile['Placement'].value_counts()
# Out:
# Yes    116
# No      84
# Name: Placement, dtype: int64

# %%
csvFile['Placement'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Placement'>

# %%
csvFile['Python'].head(10).plot.pie()
# Out:
# <Axes: ylabel='Python'>

# %%
csvFile['DeepLearning'].head(15).plot.pie()
# Out:
# <Axes: ylabel='DeepLearning'>

# %%
csvFile['MachineLearning'].head(20).plot.pie()
# Out:
# <Axes: ylabel='MachineLearning'>

# %%
csvFile['BigData'].head(10).plot.pie()
# Out:
# <Axes: ylabel='BigData'>

# %%
csvFile['CloudComputing'].head(18).plot.pie()
# Out:
# <Axes: ylabel='CloudComputing'>

# %%
plt.bar(a1,a2)
plt.xlabel('Python')
plt.ylabel('DeepLearning')
plt.show()

# %%
x=a1
y=a2
plt.scatter(x, y)
plt.xlabel('Python')
plt.ylabel('DeepLearning')
plt.show()

# %%
plt.hist(x, 100,color='magenta')
plt.xlabel('Python')
plt.ylabel('DeepLearning')
plt.show()
